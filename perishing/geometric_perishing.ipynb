# %%
import warnings;
warnings.filterwarnings('ignore');

from time import sleep
from tqdm.auto import tqdm

import sys
import importlib
import numpy as np
import nbformat
# import plotly.express
# import plotly.express as px
import pandas as pd
import cvxpy as cp
import scipy.optimize as optimization
import matplotlib.pyplot as plt
import seaborn as sns
import helper
import algorithms

# %%
num_iterations = 50

file_name = "geometric_perishing_quadratic"

mean_size = 2
var_size = .1

algo_list = ['fixed_threshold', 'hope_guardrail_12', 'hope_guardrail_13', 'og_hope_guardrail_12', 'og_hope_guardrail_13']

# %%
def perish_dist(b, n):
    val = np.minimum(n,np.random.geometric(p = 1/((n**2)*np.log(n))))
    return val

# %%
def demand_dist(n, mean_size, var_size=.1):
    size = np.maximum(0, np.random.normal(loc=mean_size, scale=np.sqrt(var_size), size=n).astype(int))
    return size

# %%
num_groups = np.logspace(2, 12, base=1.5, num=20).astype(int)

data = []

for n in tqdm(num_groups):

    n = int(n) + 5
    max_budget = mean_size*n
    print(f'Num Locations: {n}, Max Budget: {max_budget}')
    offset_prob = helper.check_offset_expiry(perish_dist, lambda n: demand_dist(n, mean_size, var_size), n, max_budget)
    print(f' Probability process is offset expiring: {100*offset_prob}')

    # CALCULATES
    n_upper = helper.n_upper(lambda n: demand_dist(n, mean_size, var_size), n)
    
    num_valid = 0    

    x_lower_perish = helper.x_lower_line_search(perish_dist, lambda n: demand_dist(n, mean_size, var_size), n, max_budget, n_upper)

    print(f'Necessary X_lower due to perishing: {x_lower_perish}')


    while num_valid < num_iterations:
        demands = demand_dist(n, mean_size, var_size)
        resource_perish = np.asarray([perish_dist(b,n) for b in range(max_budget)])

        check_optimality = [(max_budget / np.sum(demands))*np.sum(demands[:(t+1)])
                                - np.count_nonzero([resource_perish <= t]) for t in range(n)]
        if np.min(check_optimality) < 0: # checks if B/N is feasible in hindsight
            continue
        else:
            num_valid += 1
            
        xopt = max_budget / np.sum(demands)
        # Should also check feasibility of x_lower on this sample path that was sampled?
        
        for algo in algo_list:
            # print(algo)
            if algo == 'fixed_threshold':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.fixed_threshold(demands, resource_perish, max_budget, xopt, x_lower_perish, n)
            elif algo == 'hope_guardrail_12':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_perish(demands, resource_perish, max_budget, xopt, x_lower_perish, n, n**(-1/2), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'hope_guardrail_13':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_perish(demands, resource_perish, max_budget, xopt, x_lower_perish, n, n**(-1/3), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'og_hope_guardrail_12':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_original(demands, resource_perish, max_budget, xopt, x_lower_perish, n, n**(-1/2), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'og_hope_guardrail_13':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_original(demands, resource_perish, max_budget, xopt, x_lower_perish, n, n**(-1/3), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)

            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Hindsight_Envy', 'Value': hindsight_envy}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Counterfactual_Envy', 'Value': counterfactual_envy}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Waste', 'Value': waste}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Perished_Un_Allocated', 'Value': perish_un_allocate}
            data.append(data_dict)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Num Locations: 7, Max Budget: 14
#  Probability process is offset expiring: 99.9
# Starting value: 0.9469162067266176
# Final value: 0.8969162067266175
# Necessary X_lower due to perishing: 0.8969162067266175
# Num Locations: 7, Max Budget: 14
#  Probability process is offset expiring: 100.0
# Starting value: 0.9475534975171459
# Final value: 0.9075534975171459
# Necessary X_lower due to perishing: 0.9075534975171459
# Num Locations: 8, Max Budget: 16
#  Probability process is offset expiring: 100.0
# Starting value: 0.9522245766751053
# Final value: 0.9222245766751053
# Necessary X_lower due to perishing: 0.9222245766751053
# Num Locations: 9, Max Budget: 18
#  Probability process is offset expiring: 100.0
# Starting value: 0.9615778775744481
# Final value: 0.9315778775744481
# Necessary X_lower due to perishing: 0.9315778775744481
# Num Locations: 10, Max Budget: 20
#  Probability process is offset expiring: 100.0
# Starting value: 0.9630902971325714
# Final value: 0.9330902971325714
# Necessary X_lower due to perishing: 0.9330902971325714
# Num Locations: 11, Max Budget: 22
#  Probability process is offset expiring: 99.9
# Starting value: 0.9809988441043394
# Final value: 0.9509988441043393
# Necessary X_lower due to perishing: 0.9509988441043393
# Num Locations: 13, Max Budget: 26
#  Probability process is offset expiring: 100.0
# Starting value: 0.9812986465474549
# Final value: 0.9612986465474549
# Necessary X_lower due to perishing: 0.9612986465474549
# Num Locations: 15, Max Budget: 30
#  Probability process is offset expiring: 100.0
# Starting value: 0.9941417987039527
# Final value: 0.9741417987039527
# Necessary X_lower due to perishing: 0.9741417987039527
# Num Locations: 17, Max Budget: 34
#  Probability process is offset expiring: 100.0
# Starting value: 0.9996514164631061
# Final value: 0.9896514164631061
# Necessary X_lower due to perishing: 0.9896514164631061
# Num Locations: 20, Max Budget: 40
#  Probability process is offset expiring: 100.0
# Starting value: 1.0175049392990136
# Final value: 0.9975049392990136
# Necessary X_lower due to perishing: 0.9975049392990136
# Num Locations: 24, Max Budget: 48
#  Probability process is offset expiring: 100.0
# Starting value: 1.0268282066391228
# Final value: 1.0168282066391228
# Necessary X_lower due to perishing: 1.0168282066391228
# Num Locations: 28, Max Budget: 56
#  Probability process is offset expiring: 100.0
# Starting value: 1.0322500973695035
# Final value: 1.0222500973695035
# Necessary X_lower due to perishing: 1.0222500973695035
# Num Locations: 34, Max Budget: 68
#  Probability process is offset expiring: 100.0
# Starting value: 1.048082450495096
# Final value: 1.038082450495096
# Necessary X_lower due to perishing: 1.038082450495096
# Num Locations: 41, Max Budget: 82
#  Probability process is offset expiring: 100.0
# Starting value: 1.052742004592613
# Final value: 1.042742004592613
# Necessary X_lower due to perishing: 1.042742004592613
# Num Locations: 49, Max Budget: 98
#  Probability process is offset expiring: 100.0
# Starting value: 1.0613201464313426
# Final value: 1.0513201464313426
# Necessary X_lower due to perishing: 1.0513201464313426
# Num Locations: 60, Max Budget: 120
#  Probability process is offset expiring: 100.0
# Starting value: 1.075459644254334
# Final value: 1.065459644254334
# Necessary X_lower due to perishing: 1.065459644254334
# Num Locations: 73, Max Budget: 146
#  Probability process is offset expiring: 100.0
# Starting value: 1.0836604768817097
# Final value: 1.0736604768817097
# Necessary X_lower due to perishing: 1.0736604768817097
# Num Locations: 89, Max Budget: 178
#  Probability process is offset expiring: 100.0
# Starting value: 1.0911890761360024
# Final value: 1.0811890761360023
# Necessary X_lower due to perishing: 1.0811890761360023
# Num Locations: 109, Max Budget: 218
#  Probability process is offset expiring: 100.0
# Starting value: 1.1054322904187415
# Final value: 1.0954322904187415
# Necessary X_lower due to perishing: 1.0954322904187415
# Num Locations: 134, Max Budget: 268
#  Probability process is offset expiring: 100.0
# Starting value: 1.1157737047937013
# Final value: 1.1057737047937013
# Necessary X_lower due to perishing: 1.1057737047937013

# %%
df = pd.DataFrame.from_records(data)
df.to_csv('./data/'+file_name+'.csv', index=False)
df = pd.read_csv('./data/'+file_name+'.csv')

# %%
df.columns
df = df.assign(Algorithm = lambda df: df.Algorithm.replace(
    {'fixed_threshold': 'Static Allocation', 
     'hope_guardrail_13': 'Guarded Hope $L_T = T^{-1/3}$', 
     'hope_guardrail_12': 'Guarded Hope $L_T = T^{-1/2}$'}))

df['Log Value'] = np.log(df['Value'])
df['Log Timesteps'] = np.log(df['NumGroups'])

plt.style.use('PaperDoubleFig.mplstyle.txt')
plt.rc('text.latex', preamble=r'\usepackage{amsfonts}')

# Make some style choices for plotting 

dashesStyles = [[3,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1],[1000,1],[8,2]]


filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
dash_styles = ["",
               (4, 1.5),
               (1, 1),
               (3, 1, 1.5, 1),
               (5, 1, 1, 1),
               (5, 1, 2, 1, 2, 1),
               (2, 2, 3, 1.5),
               (1, 2.5, 3, 1.2)]

plt.rc('text', usetex=True)



fg, axs = plt.subplots(1,4, sharex='all', figsize=(20,6))
sns.lineplot(x='Log Timesteps', y='Log Value', hue=
             'Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)],
                     data=df[df.Norm == 'Counterfactual_Envy'], ax = axs[0], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='Log Timesteps', y='Log Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Waste'], ax = axs[1], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='Log Timesteps', y='Log Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Hindsight_Envy'], ax = axs[2], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='Log Timesteps', y='Log Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Perished_Un_Allocated'], ax = axs[3], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)


axs[0].get_legend().remove()
axs[0].set_ylabel('$\mathbb{E}[\Delta_{\it EF}]$')
axs[0].set_xlabel('Number of Rounds')

axs[1].set_ylabel('$\mathbb{E}[\Delta_{\it efficiency}]$')
axs[1].set_xlabel('Number of Rounds')
axs[1].get_legend().remove()

axs[2].get_legend().remove()
axs[2].set_ylabel(r'$\mathbb{E}[Envy]$')
axs[2].set_xlabel('Number of Rounds')


# axs[3].get_legend().remove()
axs[3].set_ylabel(r'Perished Un Allocated')
axs[3].set_xlabel('Number of Rounds')

plt.show()
# fg.savefig('./figures/'+file_name+'.pdf', bbox_inches = 'tight',pad_inches = 0.01, dpi=900)
