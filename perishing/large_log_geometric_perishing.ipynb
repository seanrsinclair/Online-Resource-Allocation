# %%
import warnings;
warnings.filterwarnings('ignore');

from time import sleep
from tqdm.auto import tqdm

import sys
import importlib
import numpy as np
import nbformat
# import plotly.express
# import plotly.express as px
import pandas as pd
import cvxpy as cp
import scipy.optimize as optimization
import matplotlib.pyplot as plt
import seaborn as sns
import helper
import algorithms

# %%
num_iterations = 100

file_name = "geometric_logarithmic_perishing_large"

mean_size = 2
var_size = .1

algo_list = ['fixed_threshold', 'hope_guardrail_14', 'hope_guardrail_12', 'hope_guardrail_13', 'og_hope_guardrail_12', 'og_hope_guardrail_13']

# %%
def perish_dist(b, n):
    val = np.minimum(n,np.random.geometric(p = 1/(2*n*np.log(n))))
    return val

# %%
def demand_dist(n, mean_size, var_size=.1):
    size = np.maximum(0, np.random.normal(loc=mean_size, scale=np.sqrt(var_size), size=n).astype(int))
    return size

# %%
num_groups = np.logspace(2, 12, base=1.5, num=25).astype(int)

data = []

for n in tqdm(num_groups):
    n = int(n) + 5
    max_budget = mean_size*n
    print(f'Num Locations: {n}, Max Budget: {max_budget}')
    offset_prob = helper.check_offset_expiry(perish_dist, lambda n: demand_dist(n, mean_size, var_size), n, max_budget)
    print(f' Probability process is offset expiring: {100*offset_prob}')

    # CALCULATES
    n_upper = helper.n_upper(lambda n: demand_dist(n, mean_size, var_size), n)
    
    num_valid = 0    

    x_lower_perish = helper.x_lower_line_search(perish_dist, lambda n: demand_dist(n, mean_size, var_size), n, max_budget, n_upper)
    x_lower_no_perish = (max_budget / n_upper[0])

    dperish = (max_budget / n_upper[0]) - x_lower_perish
    
    print(f'Necessary X_lower due to perishing: {x_lower_perish} and dperish: {dperish}')


    while num_valid < num_iterations:
        demands = demand_dist(n, mean_size, var_size)
        resource_perish = np.asarray([perish_dist(b,n) for b in range(max_budget)])

        check_optimality = [(max_budget / np.sum(demands))*np.sum(demands[:(t+1)])
                                - np.count_nonzero([resource_perish <= t]) for t in range(n)]
        if np.min(check_optimality) < 0: # checks if B/N is feasible in hindsight
            continue
        else:
            num_valid += 1
            
        xopt = max_budget / np.sum(demands)

        # print(f"Minimum L_T to get non trivial bound: {xopt - x_lower_perish} versus: {mean_size * (n**(-1/3))}")
        # Should also check feasibility of x_lower on this sample path that was sampled?
        
        for algo in algo_list:
            # print(algo)
            if algo == 'fixed_threshold':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.fixed_threshold(demands, resource_perish, max_budget, xopt, x_lower_perish, n)
            elif algo == 'hope_guardrail_12':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_perish(demands, resource_perish, max_budget, xopt, x_lower_perish, n, mean_size*(n**(-1/2)), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'hope_guardrail_13':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_perish(demands, resource_perish, max_budget, xopt, x_lower_perish, n, mean_size*(n**(-1/3)), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'hope_guardrail_14':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_perish(demands, resource_perish, max_budget, xopt, x_lower_perish, n, mean_size*(n**(-1/4)), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'og_hope_guardrail_12':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_original(demands, resource_perish, max_budget, xopt, x_lower_no_perish, n, mean_size*(n**(-1/2)), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)
            elif algo == 'og_hope_guardrail_13':
                perish_un_allocate, waste, counterfactual_envy, hindsight_envy = algorithms.hope_guardrail_original(demands, resource_perish, max_budget, xopt, x_lower_no_perish, n, mean_size*(n**(-1/3)), lambda n: demand_dist(n, mean_size, var_size), perish_dist, n_upper)

            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Hindsight_Envy', 'Value': hindsight_envy}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Counterfactual_Envy', 'Value': counterfactual_envy}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Waste', 'Value': waste}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Perished_Un_Allocated', 'Value': perish_un_allocate}
            data.append(data_dict)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Num Locations: 7, Max Budget: 14
#  Probability process is offset expiring: 99.7
# Starting value: 0.9423378210638008
# Final value: 0.8023378210638007
# Necessary X_lower due to perishing: 0.8023378210638007 and dperish: 0.14000000000000012
# Num Locations: 7, Max Budget: 14
#  Probability process is offset expiring: 99.4
# Starting value: 0.939760416680548
# Final value: 0.8097604166805479
# Necessary X_lower due to perishing: 0.8097604166805479 and dperish: 0.13000000000000012
# Num Locations: 8, Max Budget: 16
#  Probability process is offset expiring: 99.7
# Starting value: 0.9530570335718231
# Final value: 0.833057033571823
# Necessary X_lower due to perishing: 0.833057033571823 and dperish: 0.1200000000000001
# Num Locations: 8, Max Budget: 16
#  Probability process is offset expiring: 99.6
# Starting value: 0.9527811026976944
# Final value: 0.8227811026976943
# Necessary X_lower due to perishing: 0.8227811026976943 and dperish: 0.13000000000000012
# Num Locations: 9, Max Budget: 18
#  Probability process is offset expiring: 99.7
# Starting value: 0.9514272378015081
# Final value: 0.8114272378015079
# Necessary X_lower due to perishing: 0.8114272378015079 and dperish: 0.14000000000000012
# Num Locations: 10, Max Budget: 20
#  Probability process is offset expiring: 99.7
# Starting value: 0.9702812041747121
# Final value: 0.850281204174712
# Necessary X_lower due to perishing: 0.850281204174712 and dperish: 0.1200000000000001
# Num Locations: 11, Max Budget: 22
#  Probability process is offset expiring: 99.8
# Starting value: 0.9742526570326585
# Final value: 0.8642526570326584
# Necessary X_lower due to perishing: 0.8642526570326584 and dperish: 0.1100000000000001
# Num Locations: 12, Max Budget: 24
#  Probability process is offset expiring: 99.8
# Starting value: 0.9815420267858253
# Final value: 0.8615420267858251
# Necessary X_lower due to perishing: 0.8615420267858251 and dperish: 0.1200000000000001
# Num Locations: 13, Max Budget: 26
#  Probability process is offset expiring: 99.9
# Starting value: 0.9910307713298856
# Final value: 0.8610307713298855
# Necessary X_lower due to perishing: 0.8610307713298855 and dperish: 0.13000000000000023
# Num Locations: 15, Max Budget: 30
#  Probability process is offset expiring: 99.8
# Starting value: 0.9987715742587486
# Final value: 0.8887715742587485
# Necessary X_lower due to perishing: 0.8887715742587485 and dperish: 0.1100000000000001
# Num Locations: 17, Max Budget: 34
#  Probability process is offset expiring: 100.0
# Starting value: 0.9982285509693067
# Final value: 0.8882285509693066
# Necessary X_lower due to perishing: 0.8882285509693066 and dperish: 0.1100000000000001
# Num Locations: 19, Max Budget: 38
#  Probability process is offset expiring: 99.6
# Starting value: 1.0136213334547524
# Final value: 0.9036213334547523
# Necessary X_lower due to perishing: 0.9036213334547523 and dperish: 0.1100000000000001
# Num Locations: 22, Max Budget: 44
#  Probability process is offset expiring: 99.9
# Starting value: 1.018374086533187
# Final value: 0.9183740865331869
# Necessary X_lower due to perishing: 0.9183740865331869 and dperish: 0.10000000000000009
# Num Locations: 25, Max Budget: 50
#  Probability process is offset expiring: 99.9
# Starting value: 1.0174892863530796
# Final value: 0.9174892863530795
# Necessary X_lower due to perishing: 0.9174892863530795 and dperish: 0.10000000000000009
# Num Locations: 28, Max Budget: 56
#  Probability process is offset expiring: 99.9
# Starting value: 1.0335396099716518
# Final value: 0.9335396099716518
# Necessary X_lower due to perishing: 0.9335396099716518 and dperish: 0.10000000000000009
# Num Locations: 33, Max Budget: 66
#  Probability process is offset expiring: 100.0
# Starting value: 1.0476481859217321
# Final value: 0.9576481859217321
# Necessary X_lower due to perishing: 0.9576481859217321 and dperish: 0.09000000000000008
# Num Locations: 38, Max Budget: 76
#  Probability process is offset expiring: 99.9
# Starting value: 1.0534964253182635
# Final value: 0.9634964253182634
# Necessary X_lower due to perishing: 0.9634964253182634 and dperish: 0.09000000000000008
# Num Locations: 44, Max Budget: 88
#  Probability process is offset expiring: 99.8
# Starting value: 1.0591259559319899
# Final value: 0.9791259559319898
# Necessary X_lower due to perishing: 0.9791259559319898 and dperish: 0.08000000000000007
# Num Locations: 52, Max Budget: 104
#  Probability process is offset expiring: 99.9
# Starting value: 1.066435558541343
# Final value: 0.9864355585413429
# Necessary X_lower due to perishing: 0.9864355585413429 and dperish: 0.08000000000000007
# Num Locations: 60, Max Budget: 120
#  Probability process is offset expiring: 99.7
# Starting value: 1.077773601316162
# Final value: 0.997773601316162
# Necessary X_lower due to perishing: 0.997773601316162 and dperish: 0.08000000000000007
# Num Locations: 71, Max Budget: 142
#  Probability process is offset expiring: 100.0
# Starting value: 1.0837486593077246
# Final value: 1.0037486593077245
# Necessary X_lower due to perishing: 1.0037486593077245 and dperish: 0.08000000000000007
# Num Locations: 83, Max Budget: 166
#  Probability process is offset expiring: 99.7
# Starting value: 1.0952941530371991
# Final value: 1.015294153037199
# Necessary X_lower due to perishing: 1.015294153037199 and dperish: 0.08000000000000007
# Num Locations: 97, Max Budget: 194
#  Probability process is offset expiring: 100.0
# Starting value: 1.1006745429997433
# Final value: 1.0206745429997433
# Necessary X_lower due to perishing: 1.0206745429997433 and dperish: 0.08000000000000007
# Num Locations: 114, Max Budget: 228
#  Probability process is offset expiring: 99.8
# Starting value: 1.1089129598619185
# Final value: 1.0389129598619185
# Necessary X_lower due to perishing: 1.0389129598619185 and dperish: 0.07000000000000006
# Num Locations: 134, Max Budget: 268
#  Probability process is offset expiring: 100.0
# Starting value: 1.1178214983714279
# Final value: 1.0478214983714278
# Necessary X_lower due to perishing: 1.0478214983714278 and dperish: 0.07000000000000006

# %%
df = pd.DataFrame.from_records(data)
df.to_csv('./data/'+file_name+'.csv', index=False)
df = pd.read_csv('./data/'+file_name+'.csv')

# %%
df.columns
# df = df.assign(Algorithm = lambda df: df.Algorithm.replace(
#     {'fixed_threshold': 'Static Allocation', 
#      'hope_guardrail_13': 'Guarded Hope $L_T = T^{-1/3}$', 
#      'hope_guardrail_12': 'Guarded Hope $L_T = T^{-1/2}$',
#      'hope_guardrail_14': 'Guarded Hope $L_T = T^{-1/4}$',
#      'og_hope_guardrail_12': 'Original Guarded Hope $L_T = T^{-1/2}$',
#      'og_hope_guardrail_13': 'Original Guarded Hope $L_T = T^{-1/3}$'}))

df['Log Value'] = np.log(df['Value'])
df['Log NumGroups'] = np.log(df['NumGroups'])

plt.style.use('PaperDoubleFig.mplstyle.txt')
plt.rc('text.latex', preamble=r'\usepackage{amsfonts}')

# Make some style choices for plotting 

dashesStyles = [[3,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1],[1000,1],[8,2]]



filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')



dash_styles = ["",
               (4, 1.5),
               (1, 1),
               (3, 1, 1.5, 1),
               (5, 1, 1, 1),
               (5, 1, 2, 1, 2, 1),
               (2, 2, 3, 1.5),
               (1, 2.5, 3, 1.2)]

plt.rc('text', usetex=True)



fg, axs = plt.subplots(1,4, sharex='all', figsize=(20,6))
sns.lineplot(x='NumGroups', y='Value', hue=
             'Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)],
                     data=df[df.Norm == 'Counterfactual_Envy'], ax = axs[0], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Waste'], ax = axs[1], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Hindsight_Envy'], ax = axs[2], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles[0:len(algo_list)], 
             data=df[df.Norm == 'Perished_Un_Allocated'], ax = axs[3], linewidth=4, palette = sns.color_palette("colorblind", len(algo_list)),
            ci = None)

axs[0].get_legend().remove()
axs[0].set_ylabel('$\mathbb{E}[\Delta_{\it EF}]$')
axs[0].set_xlabel('Number of Rounds')

axs[1].set_ylabel('$\mathbb{E}[\Delta_{\it efficiency}]$')
axs[1].set_xlabel('Number of Rounds')
axs[1].get_legend().remove()

axs[2].get_legend().remove()
axs[2].set_ylabel(r'$\mathbb{E}[Envy]$')
axs[2].set_xlabel('Number of Rounds')


axs[3].set_ylabel(r'Perished Un Allocated')
axs[3].set_xlabel('Number of Rounds')

plt.show()
# fg.savefig('./figures/'+file_name+'.pdf', bbox_inches = 'tight',pad_inches = 0.01, dpi=900)
