# %% [markdown]
# # Multiple Type Experiment

# %%
import warnings;
warnings.filterwarnings('ignore');

from time import sleep
from tqdm.auto import tqdm

import sys
import importlib
import numpy as np
import nbformat
# import plotly.express
# import plotly.express as px
import pandas as pd
import cvxpy as cp
import scipy.optimize as optimization
import matplotlib.pyplot as plt
import seaborn as sns

from algorithms_multiple import *
from radar_plot import *

# %%
df = pd.read_csv('../MFP Regular Sites 2019 - addresses2019 updated.csv')

# %%
df.columns
# Out:
# Index(['Site Name', 'Address', 'City', 'State', 'ZIP', 'latitude', 'longitude',
#        'Number of Visits in 2019', 'Average Demand per Visit',
#        'StDev(Demand per Visit)', 'Unnamed: 10',
#        'Demand per Visit == the number of clients serviced on that visit'],
#       dtype='object')

# %%
locations = df[['latitude', 'longitude']]
data_weights = df['Average Demand per Visit']
data_stdev = df['StDev(Demand per Visit)']

# %% [markdown]
# ### Simple Test

# %%
prob, solver = generate_cvxpy_solve(2, 2)

solver(np.asarray([1., 1.]), np.asarray([[1,1],[1,1]]), np.asarray([1,1]))
# Out:
# (-7.621974162930201e-10,
#  array([[0.5, 0.5],
#         [0.5, 0.5]]))

# %%
prob, solver = generate_cvxpy_solve(5,3)

# %% [markdown]
# ### Scaling with n

# %%
data = []

np.random.seed(5)

# seed 2 - 47 locations

num_types = 3
num_resources = 5
dist_types = np.asarray([.25, .3, 1-.25-.3])
print(dist_types)

weights = np.asarray([[3.9, 3.0, 2.8, 2.7, .1], [3.9, 3.0, .1, 2.7, .1], [3.9, 3.0, 2.8, 2.7, 1.9]])
sum_of_rows = weights.sum(axis=1)
weights = weights / sum_of_rows[:, np.newaxis]

algo_list = {'Fixed Threshold': fixed_threshold,
             'Hope Guardrail $L_T = 1/2$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/2),
             'Hope Guardrail $L_T = 1/3$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/3)}
             

num_algo = len(algo_list)

num_iterations = 20

# num_iterations = 1

max_n = len(data_stdev)

print(max_n)


num_groups = np.arange(5, max_n)

# num_groups = [10]

for n in tqdm(num_groups):
    print('Num Locations: ' + str(n))

    alloc_diff = np.zeros((len(algo_list), num_iterations, n, num_types, num_resources)) 
    
    for i in range(num_iterations):
        
        index = np.random.choice(max_n, n, replace=False)
        mean_size = np.asarray([dist_types * data_weights[index].to_numpy()[j] for j in range(n)])
        stdev_size = np.asarray([(dist_types**2) * data_weights[index].to_numpy()[j] for j in range(n)])
             
        budget = np.asarray([np.sum(mean_size)]*num_resources)
        
        size = np.maximum(1, np.random.normal(mean_size, stdev_size))
        
        
        # print('Size: ' + str(size))
        total_num_types = np.sum(size, axis=0)

        
        prob, solver = generate_cvxpy_solve(num_types, num_resources)

        
        opt = offline_opt(budget, size, weights, solver)
        # print('offline opt: ' + str(opt))
        index = 0
        for algo in algo_list:
            
        
            sol, waste = algo_list[algo](budget, size, mean_size, stdev_size, weights, solver)
            # print('budget: ' + str(budget))
            # print('waste: ' + str(waste))
            # print(algo + ' : ' + str(sol))
            if np.around(np.sum(waste), 3) < 0:
                print(waste)
                print('error!')
            envy = 0
            for k in range(num_types):
                for t in range(n):
                    envy = max(envy, np.abs(np.dot(weights[k, :], opt[t, k, :] - sol[t, k, :])))
            alloc_diff[index, i, :, :, :] = opt - sol
            data_dict = {'NumGroups': n, 'Algorithm': algo, 'Norm': 'Envy', 'Value': envy}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm':algo, 'Norm': 'L1', 'Value': np.sum(np.abs(opt-sol))}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm':algo, 'Norm': 'Linf', 'Value': np.max(np.abs(opt-sol))}
            data.append(data_dict)
            data_dict = {'NumGroups': n, 'Algorithm':algo, 'Norm': 'Waste', 'Value': np.sum(waste)}
            data.append(data_dict)
            index += 1

    index = 0
    for algo in algo_list:
        ex_ante_envy = 0
        for k in range(num_types):
            for t in range(n):
                # print(alloc_diff.shape)
                avg_diff = [np.abs(np.dot(weights[k, :], alloc_diff[index, r, t, k, :])) for r in range(num_iterations)]
                ex_ante_envy = max(ex_ante_envy, np.mean(avg_diff))
        data_dict = {'NumGroups': n, 'Algorithm':algo, 'Norm': 'Ex-Ante Envy', 'Value': np.max(np.abs(np.mean(alloc_diff[index, :, :], axis=1)))}
        data.append(data_dict)
        index += 1
# Out:
# [0.25 0.3  0.45]
# 70
#   0%|          | 0/65 [00:00<?, ?it/s]
# Num Locations: 5
# Sizes!
# [469.64374713 491.88377195 699.06880464]
# Weights!
# [[0.312      0.24       0.224      0.216      0.008     ]
#  [0.39795918 0.30612245 0.01020408 0.2755102  0.01020408]
#  [0.27272727 0.20979021 0.1958042  0.18881119 0.13286713]]
# Budget!
# [1153.6 1153.6 1153.6 1153.6 1153.6]
# Solve failed retyring verbose
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 18
#   Cones                  : 3
#   Scalar variables       : 29
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 18
#   Cones                  : 3
#   Scalar variables       : 29
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 8
# Optimizer  - Cones                  : 3
# Optimizer  - Scalar variables       : 29                conic                  : 9
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 23                after factor           : 26
# Factor     - dense dim.             : 0                 flops                  : 2.06e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   7.0e+02  1.3e+00  1.4e+03  0.00e+00   -2.415306005e+00  1.374705402e+03   1.0e+00  0.01
# 1   7.1e+01  1.3e-01  4.4e+02  -9.98e-01  -9.919381227e+01  1.253111096e+03   1.0e-01  0.02
# 2   8.0e+00  1.5e-02  1.4e+02  -9.72e-01  -8.327045073e+02  3.101471779e+02   1.1e-02  0.02
# 3   1.9e+00  3.4e-03  2.9e+01  -5.22e-01  -5.868959808e+02  -1.563045543e+02  2.7e-03  0.02
# 4   4.4e-01  8.1e-04  3.6e+00  7.32e-01   1.138063528e+02   2.288038616e+02   6.2e-04  0.02
# 5   5.2e-02  9.6e-05  1.4e-01  1.03e+00   3.273682599e+02   3.408565023e+02   7.4e-05  0.02
# 6   9.4e-04  1.7e-06  3.5e-04  1.00e+00   3.553139217e+02   3.555581620e+02   1.3e-06  0.02
# 7   7.7e-05  1.4e-07  8.4e-06  9.98e-01   3.558350195e+02   3.558551007e+02   1.1e-07  0.02
# 8   6.5e-06  1.2e-08  2.0e-07  9.99e-01   3.558798413e+02   3.558815299e+02   9.3e-09  0.02
# 9   7.4e-07  1.4e-09  7.8e-09  1.00e+00   3.558837042e+02   3.558838955e+02   1.1e-09  0.02
# 10  9.8e-08  1.8e-10  3.8e-10  1.00e+00   3.558841425e+02   3.558841679e+02   1.4e-10  0.02
# 11  3.3e-08  8.3e-11  7.5e-11  1.00e+00   3.558841883e+02   3.558841970e+02   4.6e-11  0.02
# 12  3.0e-08  1.4e-10  6.4e-11  1.00e+00   3.558841907e+02   3.558841985e+02   4.1e-11  0.02
# 13  3.0e-08  7.3e-11  6.3e-11  1.00e+00   3.558841909e+02   3.558841987e+02   4.1e-11  0.02
# 14  4.2e-09  1.0e-11  3.0e-12  1.00e+00   3.558842076e+02   3.558842087e+02   5.8e-12  0.03
# Optimizer terminated. Time: 0.03
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.5588420756e+02    nrm: 1e+03    Viol.  con: 9e-15    var: 0e+00    cones: 0e+00
#   Dual.    obj: 3.5588420869e+02    nrm: 2e+00    Viol.  con: 0e+00    var: 6e-07    cones: 3e-10
# Num Locations: 6
# Num Locations: 7
# Num Locations: 8
# Sizes!
# [529.47306379 616.36500155 934.81987745]
# Weights!
# [[0.312      0.24       0.224      0.216      0.008     ]
#  [0.39795918 0.30612245 0.01020408 0.2755102  0.01020408]
#  [0.27272727 0.20979021 0.1958042  0.18881119 0.13286713]]
# Budget!
# [1373. 1373. 1373. 1373. 1373.]
# Solve failed retyring verbose
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 18
#   Cones                  : 3
#   Scalar variables       : 29
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 18
#   Cones                  : 3
#   Scalar variables       : 29
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 8
# Optimizer  - Cones                  : 3
# Optimizer  - Scalar variables       : 29                conic                  : 9
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 23                after factor           : 26
# Factor     - dense dim.             : 0                 flops                  : 2.06e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.3e+02  1.3e+00  1.7e+03  0.00e+00   -2.415306005e+00  1.722448540e+03   1.0e+00  0.01
# 1   1.7e+02  2.4e-01  7.3e+02  -9.98e-01  -6.326848976e+01  1.648330762e+03   1.8e-01  0.02
# 2   1.2e+01  1.7e-02  1.9e+02  -9.87e-01  -9.207598991e+02  5.925843030e+02   1.3e-02  0.02
# 3   4.7e+00  6.8e-03  8.5e+01  -7.01e-01  -1.201780874e+03  -1.751354734e+02  5.1e-03  0.02
# 4   2.4e+00  3.4e-03  3.5e+01  3.62e-01   -3.451860842e+02  2.776998120e+02   2.5e-03  0.02
# 5   4.6e-01  6.6e-04  2.6e+00  6.79e-01   3.643582329e+02   4.956590493e+02   4.9e-04  0.02
# 6   2.9e-02  4.2e-05  4.2e-02  9.47e-01   5.468058073e+02   5.553402621e+02   3.1e-05  0.02
# 7   5.3e-04  7.6e-07  1.0e-04  9.97e-01   5.605278202e+02   5.606832770e+02   5.6e-07  0.02
# 8   7.9e-06  1.1e-08  1.9e-07  1.00e+00   5.607561713e+02   5.607585124e+02   8.5e-09  0.02
# 9   6.1e-07  8.7e-10  4.0e-09  1.00e+00   5.607594220e+02   5.607596007e+02   6.5e-10  0.02
# 10  6.4e-08  9.7e-11  1.4e-10  1.00e+00   5.607596814e+02   5.607597004e+02   6.9e-11  0.02
# 11  1.2e-08  5.4e-11  1.1e-11  1.00e+00   5.607597068e+02   5.607597102e+02   1.6e-11  0.02
# Optimizer terminated. Time: 0.03
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 5.6075970677e+02    nrm: 1e+03    Viol.  con: 1e-14    var: 0e+00    cones: 0e+00
#   Dual.    obj: 5.6075971023e+02    nrm: 1e+00    Viol.  con: 0e+00    var: 6e-07    cones: 5e-09
# Num Locations: 9
# Num Locations: 10
# Num Locations: 11
# Num Locations: 12
# Num Locations: 13
# Num Locations: 14
# Num Locations: 15
# Num Locations: 16
# Num Locations: 17
# Num Locations: 18
# Num Locations: 19
# Num Locations: 20
# Num Locations: 21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ca241650710c> in <module>
#      42
#      43         index = np.random.choice(max_n, n, replace=False)
# ---> 44         mean_size = np.asarray([dist_types * data_weights[index].to_numpy()[j] for j in range(n)])
#      45         stdev_size = np.asarray([(dist_types**2) * data_weights[index].to_numpy()[j] for j in range(n)])
#      46
#
# <ipython-input-7-ca241650710c> in <listcomp>(.0)
#      42
#      43         index = np.random.choice(max_n, n, replace=False)
# ---> 44         mean_size = np.asarray([dist_types * data_weights[index].to_numpy()[j] for j in range(n)])
#      45         stdev_size = np.asarray([(dist_types**2) * data_weights[index].to_numpy()[j] for j in range(n)])
#      46
#
# ~/anaconda3/envs/resource_allocation/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     875             return self._get_values(key)
#     876
# --> 877         return self._get_with(key)
#     878
#     879     def _get_with(self, key):
#
# ~/anaconda3/envs/resource_allocation/lib/python3.8/site-packages/pandas/core/series.py in _get_with(self, key)
#     910             #  (i.e. self.iloc) or label-based (i.e. self.loc)
#     911             if not self.index._should_fallback_to_positional():
# --> 912                 return self.loc[key]
#     913             else:
#     914                 return self.iloc[key]
#
# KeyboardInterrupt:

# %%
# df = pd.DataFrame.from_records(data)
# df.to_csv('./data/multi_fbst.csv', index=False)
df = pd.read_csv('./data/multi_fbst.csv')

# %%
df = pd.DataFrame.from_records(data)

df.columns
# df = df.assign(Algorithm = lambda df: df.Algorithm.replace({'fixed_threshold': 'Fixed Threshold', 'hope_guardrail_13': 'Guarded Hope $L_T = T^{-1/3}$', 'hope_guardrail_12': 'Guarded Hope $L_T = T^{-1/2}$'}))

plt.style.use('PaperDoubleFig.mplstyle.txt')
# Make some style choices for plotting 
# colorWheel =['#2bd1e5',
#             '#281bf5',
#              '#db1bf5',
#              '#F5CD1B',
#             '#FF5733','#9cf51b',]
dashesStyles = [[3,1],
            [2,1,10,1],
            [4, 1, 1, 1, 1, 1]] #[1000,1],[8,2]]

print(df.head)


#filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
#plt.figure(figsize=(20,10))
#plt.title('Simple Distribution L1')
#sns.lineplot(x='NumGroups', y='value', hue='variable', data=df[df.Norm == 'L1'])

filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
dash_styles = ["",
               (4, 1.5),
               (1, 1),
               (3, 1, 1.5, 1),
               (5, 1, 1, 1),
               (5, 1, 2, 1, 2, 1),
               (2, 2, 3, 1.5),
               (1, 2.5, 3, 1.2)]

# fig = plt.figure(figsize=(20,6))
plt.rc('text', usetex=True)



fg, axs = plt.subplots(1,3, sharex='all', figsize=(20,6))
sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles,
                     data=df[df.Norm == 'Envy'], ax = axs[0], palette = sns.color_palette("colorblind", 3),
            ci = None)
sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles, 
             data=df[df.Norm == 'Waste'], ax = axs[1], palette = sns.color_palette("colorblind", 3),
            ci = None)

sns.lineplot(x='NumGroups', y='Value', hue='Algorithm', style = 'Algorithm', dashes = dashesStyles, 
             data=df[df.Norm == 'Ex-Ante Envy'], ax = axs[2], palette = sns.color_palette("colorblind", 3),
            ci = None)



axs[0].get_legend().remove()
axs[0].set_ylabel('$\Delta_{\it EF}$')
axs[0].set_xlabel('Number of Rounds')

axs[1].set_ylabel('$\Delta_{\it efficiency}$')
axs[1].set_xlabel('Number of Rounds')
axs[1].get_legend().remove()

axs[2].get_legend().remove()
axs[2].set_ylabel(r'$\Delta_{\it EF}^+$')
axs[2].set_xlabel('Number of Rounds')


axs[2].legend(ncol = 3, loc= 'upper right', bbox_to_anchor=(0.5, -.15))


# axs[2].legend(ncol = 1, loc= 'upper right')




plt.show()
fg.savefig('./figures/multi_fbst.pdf', bbox_inches = 'tight',pad_inches = 0.01, dpi=900)
# Out:
# <bound method NDFrame.head of        NumGroups                   Algorithm          Norm        Value
# 0              5             Fixed Threshold          Envy     0.616562
# 1              5             Fixed Threshold            L1    30.451250
# 2              5             Fixed Threshold          Linf     0.689320
# 3              5             Fixed Threshold         Waste  1597.752745
# 4              5  Hope Guardrail $L_T = 1/2$          Envy     0.506514
# ...          ...                         ...           ...          ...
# 15790         69  Hope Guardrail $L_T = 1/3$          Linf     0.375180
# 15791         69  Hope Guardrail $L_T = 1/3$         Waste  1284.724178
# 15792         69             Fixed Threshold  Ex-Ante Envy     0.679170
# 15793         69  Hope Guardrail $L_T = 1/2$  Ex-Ante Envy     0.361657
# 15794         69  Hope Guardrail $L_T = 1/3$  Ex-Ante Envy     0.141614
#
# [15795 rows x 4 columns]>

# %%
df.tail

# %% [markdown]
# ### Group by Group Difference

# %%
fair_data = []


algo_list = {'Fixed Threshold': fixed_threshold,
             'Hope Guardrail $L_T = 1/2$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/2),
             'Hope Guardrail $L_T = 1/3$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/3)}
             

num_algo = len(algo_list)

num_iterations = 200
n = 50

alloc_diff = np.zeros((len(algo_list), num_iterations, n, num_types, num_resources)) 

for i in tqdm(range(num_iterations)):

    index = np.random.choice(max_n, n, replace=False)
    mean_size = np.asarray([dist_types * data_weights[index].to_numpy()[j] for j in range(n)])
    stdev_size = np.asarray([(dist_types**2) * data_weights[index].to_numpy()[j] for j in range(n)])

    budget = np.asarray([np.sum(mean_size)]*num_resources)

    size = np.maximum(1, np.random.normal(mean_size, stdev_size))


    # print('Size: ' + str(size))
    total_num_types = np.sum(size, axis=0)


    prob, solver = generate_cvxpy_solve(num_types, num_resources)


    opt = offline_opt(budget, size, weights, solver)
    # print('offline opt: ' + str(opt))
    index = 0
    for algo in algo_list:

        sol, waste = algo_list[algo](budget, size, mean_size, stdev_size, weights, solver)
        prop_alloc = budget / np.sum(size)   
        true_envy = 0
        proportional = 0
        
        nsw = 1
        for k in range(num_types):
            for t in range(n):
                nsw +=  size[t,k] * np.log(np.dot(weights[k, :], sol[t, k, :]))
        nsw = max(-10000000, nsw)
        
        
        for k in range(num_types):
            proportional = max(proportional, max(np.dot(weights[k, :], prop_alloc) - np.matmul(sol[:,k,:], weights[k,:])))
        
        for k1 in range(num_types):
            for k2 in range(num_types):
                true_envy = max(envy, max(np.matmul(sol[:,k2,:], weights[k1, :])) - min(np.matmul(sol[:,k1,:], weights[k1,:])))
           
        envy = 0
        for k in range(num_types):
            for t in range(n):
                envy = max(envy, np.abs(np.dot(weights[k, :], opt[t, k, :] - sol[t, k, :])))
                
        alloc_diff[index, i, :, :, :] = opt - sol
        index += 1
        fair_data.append({'Iteration':i, 'Algorithm':algo, 
                          '$\Delta_{\it efficiency}$': np.sum(waste) / n, 
                          '$\Delta_{\it Prop}$': proportional, 
                          '\textsc{NSW}'.encode('unicode_escape').decode('utf'): nsw,
                          '\textsc{Envy}'.encode('unicode_escape').decode('utf'): true_envy, 
                          '$\Delta_{\it EF}$': envy, 
                         })
            
for i in range(n):
    data.append({'Location': i, 'Algorithm':'Zero', 'Value': 0})
    
    
index = 0
for algo in algo_list:
    ex_ante_envy = 0
    for k in range(num_types):
        for t in range(n):
            # print(alloc_diff.shape)
            avg_diff = [np.abs(np.dot(weights[k, :], alloc_diff[index, r, t, k, :])) for r in range(num_iterations)]
            ex_ante_envy = max(ex_ante_envy, np.mean(avg_diff))
    data_dict = {'Algorithm':algo, '$\Delta_{\it EF}^+$' : ex_ante_envy}
    fair_data.append(data_dict)
    index += 1
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# fair_df = pd.DataFrame.from_records(fair_data)
# fair_df.to_csv('./data/multi_fbst_fair.csv', index=False)
fair_df = pd.read_csv('./data/multi_fbst_fair.csv')

# %% [markdown]
# ### Printing Fairness Metrics

# %% [markdown]
# In hindsight proportional as the same makes sense, as it will be achieved by people obtaining X_lower, which is the same for all the algorithms (and algorithms ensure they don't run out of budget....)
#
# TODO: Add NSW, EF

# %%
# print(fair_df.columns)
fair_df = fair_df.groupby(['Algorithm']).mean()
print(fair_df.drop(['Iteration'], axis=1))

fair_df['$\Delta_{\it efficiency}$'] = (-1)*fair_df['$\Delta_{\it efficiency}$']
fair_df['\textsc{Envy}'.encode('unicode_escape').decode('utf')] = (-1)*fair_df['\textsc{Envy}'.encode('unicode_escape').decode('utf')]
fair_df['$\Delta_{\it EF}$'] = (-1)* fair_df['$\Delta_{\it EF}$']
fair_df['$\Delta_{\it Prop}$'] = (-1) * fair_df['$\Delta_{\it Prop}$']
fair_df['$\Delta_{\it EF}^+$'] = (-1)*fair_df['$\Delta_{\it EF}^+$']
# Out:
#                             $\Delta_{\it efficiency}$  $\Delta_{\it Prop}$  \
# Algorithm
# Fixed Threshold                            124.722945             0.176655
# Hope Guardrail $L_T = 1/2$                  30.289917             0.128912
# Hope Guardrail $L_T = 1/3$                  20.051281             0.142730
#
#                             \textsc{NSW}  \textsc{Envy}  $\Delta_{\it EF}$  \
# Algorithm
# Fixed Threshold              -360.287619       0.293389           0.257775
# Hope Guardrail $L_T = 1/2$    702.379225       0.263304           0.191617
# Hope Guardrail $L_T = 1/3$    757.091149       0.333361           0.292172
#
#                             $\Delta_{\it EF}^+$
# Algorithm
# Fixed Threshold                        0.257775
# Hope Guardrail $L_T = 1/2$             0.091774
# Hope Guardrail $L_T = 1/3$             0.276354

# %%
fair_df = normalize(fair_df).drop(['Iteration'], axis=1)

print(fair_df)
# Out:
#                             $\Delta_{\it efficiency}$  $\Delta_{\it Prop}$  \
# Algorithm
# Fixed Threshold                              0.100000             0.100000
# Hope Guardrail $L_T = 1/2$                   0.911965             1.000000
# Hope Guardrail $L_T = 1/3$                   1.000000             0.739522
#
#                             \textsc{NSW}  \textsc{Envy}  $\Delta_{\it EF}$  \
# Algorithm
# Fixed Threshold                 0.100000       0.613511           0.407857
# Hope Guardrail $L_T = 1/2$      0.955932       1.000000           1.000000
# Hope Guardrail $L_T = 1/3$      1.000000       0.100000           0.100000
#
#                             $\Delta_{\it EF}^+$
# Algorithm
# Fixed Threshold                        0.190587
# Hope Guardrail $L_T = 1/2$             1.000000
# Hope Guardrail $L_T = 1/3$             0.100000

# %%
# number of variable

algo_list = {'Fixed Threshold': fixed_threshold,
             'Hope Guardrail $L_T = 1/2$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/2),
             'Hope Guardrail $L_T = 1/3$': lambda a,b,c,d,e,f: hope_guardrail(a,b,c,d,e,f,1/3)}


plt.style.use('PaperDoubleFig.mplstyle.txt')


from math import pi


plt.rc('text', usetex=True)




N = len(list(fair_df))
theta = radar_factory(N, frame='polygon')

spoke_labels = list(fair_df)

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(projection='radar'))
fig.subplots_adjust(top=0.85, bottom=0.05)

ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
# ax.set_title('Comparison of Fairness Metrics',  position=(0.5, 1.1), ha='center')

index = 0
for algo in algo_list:
    values = fair_df.iloc[index, :].to_numpy()
    ax.plot(theta, values, linewidth=1, linestyle='solid', label=fair_df.index[index], color = sns.color_palette('colorblind', len(algo_list))[index])
    ax.fill(theta, values, color = sns.color_palette('colorblind', len(algo_list))[index],  alpha=0.25)
    index += 1
ax.set_varlabels(spoke_labels)

plt.legend(loc='right', bbox_to_anchor=(2.15, .5))
plt.savefig('./figures/multi_fbst_radar.pdf')
plt.show()
# plt.savefig('radar.pdf')
